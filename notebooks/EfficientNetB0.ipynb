# %% [markdown]
# #EfficientNetB0

# %% [markdown]
# ##Importações

# %%
# !git clone https://github.com/IagoMagalhaes23/Pandora.git

import os
import cv2
import random
import numpy as np
import tracemalloc
import pandas as pd
from time import time_ns
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, roc_curve, auc
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, MaxPool2D, Flatten, Dropout, BatchNormalization

# %cd Pandora
from utils import functions as fct
# Out:
# Cloning into 'Pandora'...
# remote: Enumerating objects: 1102, done.
# remote: Counting objects: 100% (1102/1102), done.
# remote: Compressing objects: 100% (602/602), done.
# remote: Total 1102 (delta 334), reused 1048 (delta 283), pack-reused 0
# Receiving objects: 100% (1102/1102), 13.80 MiB | 17.28 MiB/s, done.
# Resolving deltas: 100% (334/334), done.
# /content/Pandora

# %% [markdown]
# ##Carregando dados

# %%
caminho_train = 'dataset/recortado/train'
caminho_test = 'dataset/recortado/test'
caminho_valid = 'dataset/recortado/valid'

callback = EarlyStopping(monitor='loss', patience=5, mode='min')

data_train = fct.readFiles(caminho_train)
data_test= fct.readFiles(caminho_test)
data_valid = fct.readFiles(caminho_valid)

random.shuffle(data_train)
random.shuffle(data_test)
random.shuffle(data_valid)

df_train = pd.DataFrame(data_train, columns=['image', 'label'])
df_test = pd.DataFrame(data_test, columns=['image', 'label'])
df_valid = pd.DataFrame(data_valid, columns=['image', 'label'])

df_train = df_train.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)
df_valid = df_valid.reset_index(drop = True)

print('----------------------------- SHAPES DF -----------------------------')
print(df_train.shape)
print(df_valid.shape)
print(df_test.shape)
print('---------------------------------------------------------------------')

X_train, y_train = fct.compose_dataset(df_train)
X_test, y_test = fct.compose_dataset(df_test)
X_valid, y_valid = fct.compose_dataset(df_valid)

print('----------------------------- SHAPES LABEL -----------------------------')
print('Treino shape: {}, Labels shape: {}'.format(X_train.shape, y_train.shape))
print('Valid shape: {}, Labels shape: {}'.format(X_valid.shape, y_valid.shape))
print('Teste shape: {}, Labels shape: {}'.format(X_test.shape, y_test.shape))
print('------------------------------------------------------------------------')

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range = 0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(X_train)
datagen.fit(X_test)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_valid = to_categorical(y_valid)
# Out:
# ----------------------------- SHAPES DF -----------------------------
# (169, 2)
# (20, 2)
# (20, 2)
# ---------------------------------------------------------------------
# ----------------------------- SHAPES LABEL -----------------------------
# Treino shape: (169, 224, 224, 1), Labels shape: (169,)
# Valid shape: (20, 224, 224, 1), Labels shape: (20,)
# Teste shape: (20, 224, 224, 1), Labels shape: (20,)
# ------------------------------------------------------------------------

# %% [markdown]
# ##Treinando modelo

# %%
def efficientnetB0():
    NUM_CLASSES = 5
    IMG_SIZE = 224
    size = (IMG_SIZE, IMG_SIZE)

    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 1))

    # Using model without transfer learning

    outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(inputs)

    model = tf.keras.Model(inputs, outputs)

    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"] )

    model.summary()

    return model


modelo = efficientnetB0()
epochs = 100
history = modelo.fit(X_train, y_train, epochs=epochs, verbose=2)

modelo.save(filepath='efficientnetb0.hdf5')
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  efficientnetb0 (Functional  (None, 5)                 4055976
#  )
#
# =================================================================
# Total params: 4055976 (15.47 MB)
# Trainable params: 4013953 (15.31 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________
# Epoch 1/100
# 6/6 - 39s - loss: 6.1774 - accuracy: 0.1598 - 39s/epoch - 6s/step
# Epoch 2/100
# 6/6 - 1s - loss: 2.7845 - accuracy: 0.2663 - 1s/epoch - 225ms/step
# Epoch 3/100
# 6/6 - 1s - loss: 2.0520 - accuracy: 0.3550 - 1s/epoch - 230ms/step
# Epoch 4/100
# 6/6 - 1s - loss: 2.5375 - accuracy: 0.3136 - 1s/epoch - 235ms/step
# Epoch 5/100
# 6/6 - 1s - loss: 2.2606 - accuracy: 0.3136 - 1s/epoch - 225ms/step
# Epoch 6/100
# 6/6 - 1s - loss: 1.9272 - accuracy: 0.4734 - 1s/epoch - 224ms/step
# Epoch 7/100
# 6/6 - 1s - loss: 2.1471 - accuracy: 0.4675 - 1s/epoch - 226ms/step
# Epoch 8/100
# 6/6 - 1s - loss: 1.8528 - accuracy: 0.5680 - 1s/epoch - 229ms/step
# Epoch 9/100
# 6/6 - 1s - loss: 1.8478 - accuracy: 0.5562 - 1s/epoch - 228ms/step
# Epoch 10/100
# 6/6 - 1s - loss: 1.7001 - accuracy: 0.5917 - 1s/epoch - 227ms/step
# Epoch 11/100
# 6/6 - 1s - loss: 1.7501 - accuracy: 0.6154 - 1s/epoch - 227ms/step
# Epoch 12/100
# 6/6 - 1s - loss: 0.9167 - accuracy: 0.6450 - 1s/epoch - 231ms/step
# Epoch 13/100
# 6/6 - 1s - loss: 1.2621 - accuracy: 0.6923 - 1s/epoch - 235ms/step
# Epoch 14/100
# 6/6 - 1s - loss: 0.7815 - accuracy: 0.8284 - 1s/epoch - 229ms/step
# Epoch 15/100
# 6/6 - 1s - loss: 0.6857 - accuracy: 0.8284 - 1s/epoch - 227ms/step
# Epoch 16/100
# 6/6 - 1s - loss: 0.5642 - accuracy: 0.8639 - 1s/epoch - 228ms/step
# Epoch 17/100
# 6/6 - 1s - loss: 0.8783 - accuracy: 0.7929 - 1s/epoch - 228ms/step
# Epoch 18/100
# 6/6 - 1s - loss: 1.0724 - accuracy: 0.7633 - 1s/epoch - 230ms/step
# Epoch 19/100
# 6/6 - 1s - loss: 0.9987 - accuracy: 0.8166 - 1s/epoch - 228ms/step
# Epoch 20/100
# 6/6 - 1s - loss: 0.8137 - accuracy: 0.7692 - 1s/epoch - 230ms/step
# Epoch 21/100
# 6/6 - 1s - loss: 1.0615 - accuracy: 0.7811 - 1s/epoch - 232ms/step
# Epoch 22/100
# 6/6 - 1s - loss: 1.2322 - accuracy: 0.7929 - 1s/epoch - 233ms/step
# Epoch 23/100
# 6/6 - 1s - loss: 0.7175 - accuracy: 0.8225 - 1s/epoch - 228ms/step
# Epoch 24/100
# 6/6 - 1s - loss: 1.0617 - accuracy: 0.7633 - 1s/epoch - 225ms/step
# Epoch 25/100
# 6/6 - 1s - loss: 1.1497 - accuracy: 0.7515 - 1s/epoch - 226ms/step
# Epoch 26/100
# 6/6 - 1s - loss: 0.7066 - accuracy: 0.8225 - 1s/epoch - 227ms/step
# Epoch 27/100
# 6/6 - 1s - loss: 0.7502 - accuracy: 0.8402 - 1s/epoch - 227ms/step
# Epoch 28/100
# 6/6 - 1s - loss: 0.4384 - accuracy: 0.8580 - 1s/epoch - 227ms/step
# Epoch 29/100
# 6/6 - 1s - loss: 0.9555 - accuracy: 0.8402 - 1s/epoch - 227ms/step
# Epoch 30/100
# 6/6 - 2s - loss: 0.5768 - accuracy: 0.8698 - 2s/epoch - 282ms/step
# Epoch 31/100
# 6/6 - 2s - loss: 0.4988 - accuracy: 0.8166 - 2s/epoch - 278ms/step
# Epoch 32/100
# 6/6 - 1s - loss: 0.3511 - accuracy: 0.9290 - 1s/epoch - 225ms/step
# Epoch 33/100
# 6/6 - 1s - loss: 0.3217 - accuracy: 0.8817 - 1s/epoch - 224ms/step
# Epoch 34/100
# 6/6 - 1s - loss: 0.1964 - accuracy: 0.9408 - 1s/epoch - 226ms/step
# Epoch 35/100
# 6/6 - 1s - loss: 0.2720 - accuracy: 0.9231 - 1s/epoch - 225ms/step
# Epoch 36/100
# 6/6 - 1s - loss: 0.4652 - accuracy: 0.8994 - 1s/epoch - 228ms/step
# Epoch 37/100
# 6/6 - 1s - loss: 0.6750 - accuracy: 0.8462 - 1s/epoch - 226ms/step
# Epoch 38/100
# 6/6 - 1s - loss: 0.7374 - accuracy: 0.7870 - 1s/epoch - 224ms/step
# Epoch 39/100
# 6/6 - 1s - loss: 0.8171 - accuracy: 0.7811 - 1s/epoch - 234ms/step
# Epoch 40/100
# 6/6 - 1s - loss: 0.7765 - accuracy: 0.8994 - 1s/epoch - 229ms/step
# Epoch 41/100
# 6/6 - 1s - loss: 0.5160 - accuracy: 0.8817 - 1s/epoch - 225ms/step
# Epoch 42/100
# 6/6 - 1s - loss: 0.3652 - accuracy: 0.9053 - 1s/epoch - 227ms/step
# Epoch 43/100
# 6/6 - 1s - loss: 0.5435 - accuracy: 0.9112 - 1s/epoch - 227ms/step
# Epoch 44/100
# 6/6 - 1s - loss: 0.2876 - accuracy: 0.9349 - 1s/epoch - 223ms/step
# Epoch 45/100
# 6/6 - 1s - loss: 0.3258 - accuracy: 0.9112 - 1s/epoch - 229ms/step
# Epoch 46/100
# 6/6 - 1s - loss: 0.2513 - accuracy: 0.9290 - 1s/epoch - 232ms/step
# Epoch 47/100
# 6/6 - 1s - loss: 0.4466 - accuracy: 0.8935 - 1s/epoch - 226ms/step
# Epoch 48/100
# 6/6 - 1s - loss: 0.4354 - accuracy: 0.8757 - 1s/epoch - 235ms/step
# Epoch 49/100
# 6/6 - 1s - loss: 0.3870 - accuracy: 0.9053 - 1s/epoch - 229ms/step
# Epoch 50/100
# 6/6 - 1s - loss: 0.4292 - accuracy: 0.8876 - 1s/epoch - 225ms/step
# Epoch 51/100
# 6/6 - 1s - loss: 0.2764 - accuracy: 0.9290 - 1s/epoch - 226ms/step
# Epoch 52/100
# 6/6 - 1s - loss: 0.2463 - accuracy: 0.9172 - 1s/epoch - 224ms/step
# Epoch 53/100
# 6/6 - 1s - loss: 0.4650 - accuracy: 0.9053 - 1s/epoch - 226ms/step
# Epoch 54/100
# 6/6 - 1s - loss: 0.3968 - accuracy: 0.9053 - 1s/epoch - 225ms/step
# Epoch 55/100
# 6/6 - 1s - loss: 0.2299 - accuracy: 0.9527 - 1s/epoch - 225ms/step
# Epoch 56/100
# 6/6 - 1s - loss: 0.2328 - accuracy: 0.9408 - 1s/epoch - 225ms/step
# Epoch 57/100
# 6/6 - 1s - loss: 0.2413 - accuracy: 0.9290 - 1s/epoch - 232ms/step
# Epoch 58/100
# 6/6 - 1s - loss: 0.2508 - accuracy: 0.9763 - 1s/epoch - 231ms/step
# Epoch 59/100
# 6/6 - 1s - loss: 0.1329 - accuracy: 0.9645 - 1s/epoch - 225ms/step
# Epoch 60/100
# 6/6 - 1s - loss: 0.1594 - accuracy: 0.9586 - 1s/epoch - 225ms/step
# Epoch 61/100
# 6/6 - 1s - loss: 0.2209 - accuracy: 0.9349 - 1s/epoch - 226ms/step
# Epoch 62/100
# 6/6 - 1s - loss: 0.1686 - accuracy: 0.9527 - 1s/epoch - 226ms/step
# Epoch 63/100
# 6/6 - 1s - loss: 0.5076 - accuracy: 0.9527 - 1s/epoch - 226ms/step
# Epoch 64/100
# 6/6 - 1s - loss: 0.1337 - accuracy: 0.9349 - 1s/epoch - 225ms/step
# Epoch 65/100
# 6/6 - 1s - loss: 0.2744 - accuracy: 0.9290 - 1s/epoch - 225ms/step
# Epoch 66/100
# 6/6 - 1s - loss: 0.2209 - accuracy: 0.9763 - 1s/epoch - 231ms/step
# Epoch 67/100
# 6/6 - 1s - loss: 0.1878 - accuracy: 0.9408 - 1s/epoch - 232ms/step
# Epoch 68/100
# 6/6 - 1s - loss: 0.0856 - accuracy: 0.9704 - 1s/epoch - 226ms/step
# Epoch 69/100
# 6/6 - 1s - loss: 0.0678 - accuracy: 0.9645 - 1s/epoch - 226ms/step
# Epoch 70/100
# 6/6 - 1s - loss: 0.0414 - accuracy: 0.9882 - 1s/epoch - 227ms/step
# Epoch 71/100
# 6/6 - 1s - loss: 0.0746 - accuracy: 0.9882 - 1s/epoch - 226ms/step
# Epoch 72/100
# 6/6 - 1s - loss: 0.0955 - accuracy: 0.9822 - 1s/epoch - 225ms/step
# Epoch 73/100
# 6/6 - 1s - loss: 0.1101 - accuracy: 0.9645 - 1s/epoch - 225ms/step
# Epoch 74/100
# 6/6 - 1s - loss: 0.0750 - accuracy: 0.9763 - 1s/epoch - 225ms/step
# Epoch 75/100
# 6/6 - 1s - loss: 0.1506 - accuracy: 0.9527 - 1s/epoch - 232ms/step
# Epoch 76/100
# 6/6 - 1s - loss: 0.1258 - accuracy: 0.9704 - 1s/epoch - 231ms/step
# Epoch 77/100
# 6/6 - 1s - loss: 0.1693 - accuracy: 0.9645 - 1s/epoch - 227ms/step
# Epoch 78/100
# 6/6 - 1s - loss: 0.0674 - accuracy: 0.9822 - 1s/epoch - 227ms/step
# Epoch 79/100
# 6/6 - 1s - loss: 0.0798 - accuracy: 0.9763 - 1s/epoch - 226ms/step
# Epoch 80/100
# 6/6 - 1s - loss: 0.0735 - accuracy: 0.9822 - 1s/epoch - 226ms/step
# Epoch 81/100
# 6/6 - 1s - loss: 0.0607 - accuracy: 0.9822 - 1s/epoch - 226ms/step
# Epoch 82/100
# 6/6 - 1s - loss: 0.1427 - accuracy: 0.9763 - 1s/epoch - 228ms/step
# Epoch 83/100
# 6/6 - 1s - loss: 0.1574 - accuracy: 0.9408 - 1s/epoch - 225ms/step
# Epoch 84/100
# 6/6 - 1s - loss: 0.2144 - accuracy: 0.9645 - 1s/epoch - 230ms/step
# Epoch 85/100
# 6/6 - 1s - loss: 0.1962 - accuracy: 0.9527 - 1s/epoch - 230ms/step
# Epoch 86/100
# 6/6 - 1s - loss: 0.1639 - accuracy: 0.9645 - 1s/epoch - 225ms/step
# Epoch 87/100
# 6/6 - 1s - loss: 0.2751 - accuracy: 0.9586 - 1s/epoch - 226ms/step
# Epoch 88/100
# 6/6 - 1s - loss: 0.1725 - accuracy: 0.9467 - 1s/epoch - 226ms/step
# Epoch 89/100
# 6/6 - 1s - loss: 0.0743 - accuracy: 0.9822 - 1s/epoch - 225ms/step
# Epoch 90/100
# 6/6 - 1s - loss: 0.0522 - accuracy: 0.9882 - 1s/epoch - 226ms/step
# Epoch 91/100
# 6/6 - 1s - loss: 0.2125 - accuracy: 0.9704 - 1s/epoch - 225ms/step
# Epoch 92/100
# 6/6 - 1s - loss: 0.0475 - accuracy: 0.9822 - 1s/epoch - 225ms/step
# Epoch 93/100
# 6/6 - 1s - loss: 0.1903 - accuracy: 0.9112 - 1s/epoch - 230ms/step
# Epoch 94/100
# 6/6 - 1s - loss: 0.1455 - accuracy: 0.9704 - 1s/epoch - 230ms/step
# Epoch 95/100
# 6/6 - 1s - loss: 0.1112 - accuracy: 0.9704 - 1s/epoch - 225ms/step
# Epoch 96/100
# 6/6 - 1s - loss: 0.0748 - accuracy: 0.9882 - 1s/epoch - 227ms/step
# Epoch 97/100
# 6/6 - 1s - loss: 0.0256 - accuracy: 0.9882 - 1s/epoch - 227ms/step
# Epoch 98/100
# 6/6 - 1s - loss: 0.0974 - accuracy: 0.9586 - 1s/epoch - 225ms/step
# Epoch 99/100
# 6/6 - 1s - loss: 0.0432 - accuracy: 0.9822 - 1s/epoch - 225ms/step
# Epoch 100/100
# 6/6 - 1s - loss: 0.0602 - accuracy: 0.9763 - 1s/epoch - 226ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##Avaliando resultados

# %%
fct.plot_hist(history)

modelo = load_model('efficientnetb0.hdf5')
print('Avaliando resultados da rede CNN')

print('Conjunto de treino')
y_pred = modelo.predict(X_train, batch_size=1)
y_pred=np.argmax(y_pred, axis=1)
y_train=np.argmax(y_train, axis=1)
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

recall_macro = recall_score(y_train, y_pred, average='macro')
precision_macro = precision_score(y_train, y_pred, average='macro')
accuracy = accuracy_score(y_train, y_pred)
print('Acurácia: {}%'.format(accuracy))
print('Recall: {}%'.format(recall_macro))
print('Precisão: {}%'.format(precision_macro))

cmtrain = confusion_matrix(y_train, y_pred)
fct.plot_confusion_matrix(cm = cmtrain, normalize = False, target_names = ['A', 'B', 'C', 'D', 'E'], title = "Matriz de confusão EfficientNetB0 - Treino")
plt.show()

print('Conjunto de teste')
y_pred = modelo.predict(X_test, batch_size=1)
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

recall_macro = recall_score(y_test, y_pred, average='macro')
precision_macro = precision_score(y_test, y_pred, average='macro')
accuracy = accuracy_score(y_test, y_pred)
print('Acurácia: {}%'.format(accuracy))
print('Recall: {}%'.format(recall_macro))
print('Precisão: {}%'.format(precision_macro))

cmt = confusion_matrix(y_test, y_pred)
fct.plot_confusion_matrix(cm = cmt, normalize = False, target_names = ['A', 'B', 'C', 'D', 'E'], title = "Matriz de confusão EfficientNetB0 - Teste")
plt.show()

print('Conjunto de validação')
y_pred = modelo.predict(X_valid, batch_size=1)
y_pred=np.argmax(y_pred, axis=1)
y_valid=np.argmax(y_valid, axis=1)
# cm = confusion_matrix(y_valid, y_pred)
# print(cm)

recall_macro = recall_score(y_valid, y_pred, average='macro')
precision_macro = precision_score(y_valid, y_pred, average='macro')
accuracy = accuracy_score(y_valid, y_pred)
print('Acurácia: {}%'.format(accuracy))
print('Recall: {}%'.format(recall_macro))
print('Precisão: {}%'.format(precision_macro))

cmv = confusion_matrix(y_valid, y_pred)
fct.plot_confusion_matrix(cm = cmv, normalize = False, target_names = ['A', 'B', 'C', 'D', 'E'], title = "Matriz de confusão EfficientNetB0 - Validação")
plt.show()
# Out:
# Avaliando resultados da rede CNN
# Conjunto de treino
# 169/169 [==============================] - 4s 10ms/step
# Acurácia: 0.14792899408284024%
# Recall: 0.2%
# Precisão: 0.02958579881656805%
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Conjunto de teste
# 20/20 [==============================] - 0s 18ms/step
# Acurácia: 0.65%
# Recall: 0.3333333333333333%
# Precisão: 0.21666666666666667%
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Conjunto de validação
# 20/20 [==============================] - 0s 16ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Acurácia: 0.2%
# Recall: 0.2%
# Precisão: 0.04%

# %% [markdown]
# ##Realizando predições

# %%
i = 1
fig=plt.figure(figsize=(10, 10))

dados = []
tempoMedio = 0

for caminho, _, arquivo in os.walk('dataset/recortado/valid'):
    caminho = str(caminho.replace("\\", "/"))
    for file in arquivo:
        dados.append(os.path.join(caminho + '/' + file[:-3] + 'png'))

for nome in dados:
    im = cv2.imread(nome)
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    imres = cv2.resize(gray, (224, 224), interpolation=cv2.INTER_CUBIC)
    imres = cv2.GaussianBlur(imres, ( 3, 3), 0)
    image = fct.prepararImagem(imres)

    fig.add_subplot(5, 4, i)
    i = i + 1
    plt.imshow(im)
    plt.axis('off')

    init = time_ns()
    ret = modelo.predict(image, batch_size=1)
    end = time_ns()
    media = end - init
    media = media  / 1e9
    tempoMedio = tempoMedio + media

    plt.title(fct.mostraCateg(ret))
plt.show()

print('Média de tempo por imagem: {0:.5f}s'.format(tempoMedio / 20))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# Média de tempo por imagem: 0.17705s
